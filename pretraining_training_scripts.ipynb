# %%
import pandas as pd
import os

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), 416 bytes | 416.00 KiB/s, done.
# From https://github.com/hareld10/ex3
#    1951495..b35d42b  master     -> origin/master
# Updating 1951495..b35d42b
# Fast-forward
#  simclr.py | 5 ++++-
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
# !python run.py -data colab_train.pkl -dataset-name 'mura' -a "resnet50" --log-every-n-steps 100 --epochs 100  -b 32 --body_part "XR_ELBOW"
# Out:
# loaded MURA Dataset (4931, 5)
# /home/hdamari/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hdamari/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0%|                                                   | 0/154 [00:00<?, ?it/s]/home/hdamari/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:814: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# ...

# %%
# !python run.py -data colab_train.pkl -dataset-name 'mura' -a "resnet50" --log-every-n-steps 100 --epochs 100  -b 32 --body_part "XR_SHOULDER"
# Out:
# loaded MURA Dataset (8379, 5)
# /home/hdamari/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hdamari/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0%|                                                   | 0/261 [00:00<?, ?it/s]/home/hdamari/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:814: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# ...

# %%
# !python run.py -data colab_train.pkl -dataset-name 'mura' -a "resnet50" --log-every-n-steps 100 --epochs 100  -b 32 --body_part "XR_HAND"
# Out:
# loaded MURA Dataset (5543, 5)
# /home/hdamari/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hdamari/venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#   0%|                                                   | 0/173 [00:00<?, ?it/s]/home/hdamari/venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:814: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# ...
